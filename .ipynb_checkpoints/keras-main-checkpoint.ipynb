# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from datagen import SequenceDataGenerator

# %%
dg = SequenceDataGenerator(num_shape = 3, image_size = 256, sequence_len = 20)

# %%
dg.init_shapes()
sequence = dg.render_sequence()
for image_info in sequence:
    plt.figure()
    plt.imshow(image_info['image'])
